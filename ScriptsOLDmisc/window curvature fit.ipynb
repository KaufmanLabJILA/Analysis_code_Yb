# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
def circle(x, r, a):
    return (np.sqrt((r**2 - (x)**2)) + a)

# %% [markdown]
# xdata = np.multiply(np.arange(0.0, 11.0, 1.0), 10**3)
# ydata = np.multiply([-6.149450198977773, -6.127179946813316, -6.060433552539095, -5.950037386584713, -5.797198360400411, -5.603618264901242, -5.371608106337308, -5.103571263076437, -4.803037087359992, -4.4733066391815994, -4.1187962409880985], 0.1)
# w=ydata[0]
# ydata = [-w+y for y in ydata]
# #data in um

# %% [markdown]
# guess_r = -xdata[-1] / np.tan(2*np.arctan(xdata[-1]/ydata[-1]))
# guess = [guess_r, -guess_r+ydata[0]]
# popt, pcov = curve_fit(circle, xdata, ydata, p0=guess)

# %% [markdown]
# x_fit = np.arange(0.0, 11.0*10**3, 100)
# y_fit = -circle(x_fit, popt[0], popt[1])-y_fit[0]
#
# plt.figure()
# plt.plot(xdata*10**(-3), ydata, 'k.')
# plt.plot(x_fit*10**(-3), y_fit, 'r-')
# plt.xlabel('pos from center of the window (mm)')
# plt.ylabel('deformation (um)')
# plt.title('diameter of the window: 45 mm')
#
# plt.show()
#
# print('radius of curvature', popt[0]*10**(-6), 'm')

# %%
xdata = np.multiply(np.arange(0.5, 11.5, 0.5), 10**3)
ydata = np.multiply([-6.50562134517556E-7, -6.495592321855284E-7, -6.475315056413995E-7, -6.455219954583489E-7, 
                     -6.435998094671529E-7, -6.395110742495368E-7, -6.357334853307976E-7, -6.315754827729816E-7, 
                     -6.263160378149322E-7, -6.207900245104035E-7, -6.147934209884887E-7, -6.079466797019823E-7, 
                     -6.004781097804319E-7, -5.926535263588412E-7, -5.842260460266859E-7, -5.751456065597526E-7, 
                     -5.653603051226519E-7, -5.551883804577404E-7, -5.442811253434434E-7, -5.32938065514117E-7, 
                     -5.209518804639182E-7, -5.083926447236107E-7], 10**6)
w=ydata[0]
ydata = [-w+y for y in ydata]
#data in um

# %%
guess_r = -xdata[-1] / np.tan(2*np.arctan(xdata[-1]/ydata[-1]))
guess = [guess_r, -guess_r+ydata[0]]
popt, pcov = curve_fit(circle, xdata, ydata, p0=guess)
print(guess)
# Out:
# [425548407.59058076, -425548407.59058076]

# %%
x_fit = np.arange(0.0, 11.5*10**3, 100)
y_fit = -circle(x_fit, popt[0], popt[1])
u = y_fit[0]
y_fit = [-u+y for y in y_fit]

plt.figure()
plt.plot(xdata*10**(-3), ydata, 'k.')
plt.plot(x_fit*10**(-3), y_fit, 'r-')
plt.xlabel('pos from center of the window (mm)')
plt.ylabel('deformation (um)')
plt.title('diameter of the window: 45 mm')

plt.show()

print('radius of curvature:', popt[0]*10**(-6), 'm')
# Out:
# radius of curvature: 432.9123579978347 m

# %%
#x dir

# %%
xdata = np.multiply(np.arange(-11.25, 11.75, 0.5), 10**3)
ydata = np.multiply([1.793717628525659E-7, 1.899929467069049E-7, 2.032353610427067E-7, 2.141710095817382E-7, 
                    2.2464453775786491E-7, 2.350292298994125E-7, 2.4363154018329835E-7, 2.5427396949903217E-7, 
                    2.611472803976191E-7, 2.6927557216063246E-7, 2.7774168927310707E-7, 2.8391377499426097E-7, 
                    2.886885651198405E-7, 2.9522790862725396E-7, 3.005372809314887E-7, 3.0402671203234796E-7, 
                    3.0862843732152336E-7, 3.1192466368558257E-7, 3.14603676845565E-7, 3.1668216838645516E-7, 
                    3.1799541709450597E-7, 3.1934559446195294E-7, 3.2006979842347845E-7, 3.2028998877604515E-7, 
                    3.1921570860081547E-7, 3.1894023790281873E-7,  3.169575301800626E-7, 3.148738793677624E-7, 
                    3.1306252087201524E-7, 3.091955013269756E-7, 3.0498699089396595E-7, 3.007385816782849E-7, 
                    2.9609935070738637E-7, 2.897842638829029E-7, 2.8398783020732143E-7, 2.770952584368937E-7, 
                    2.7065327901140153E-7, 2.6397770050969745E-7, 2.5462936918177924E-7, 2.4608046817583117E-7, 
                    2.3690447476628041E-7, 2.264476393969468E-7, 2.1555494849338168E-7, 2.045459001120219E-7, 
                    1.9259038451647863E-7, 1.8045972455971254E-7], 10**6)
#w=np.max(ydata)
#ydata = [-w+y for y in ydata]
#data in um

# %%
guess_r = -xdata[-1] / np.tan(2*np.arctan(xdata[-1]/ydata[-1]))
guess = [guess_r, -guess_r+ydata[0]]
popt, pcov = curve_fit(circle, xdata, ydata, p0=guess)
print(guess)
# Out:
# [350666887.7949781, -350666887.6156063]

# %%
x_fit = np.arange(-11.5*10**3, 11.5*10**3, 100)
y_fit = circle(x_fit, popt[0], popt[1])
#u = np.max(y_fit)
#y_fit = [-u+y for y in y_fit]

plt.figure()
plt.plot(xdata*10**(-3), ydata, 'k.')
plt.plot(x_fit*10**(-3), y_fit, 'r-')
plt.xlabel('pos from center of the window (mm)')
plt.ylabel('deformation (um)')
plt.title('diameter of the window: 45 mm')

plt.show()

print('radius of curvature:', popt[0]*10**(-6), 'm')
# Out:
# radius of curvature: 352.46685684918975 m

# %%
#y dir

# %%
xdata = np.multiply(np.arange(-11.25, 11.75, 0.5), 10**3)
ydata = np.multiply([1.4959448130650004E-7, 1.6177021746910015E-7, 1.757188664805475E-7, 1.8758541517958419E-7,
                     1.994052227894942E-7, 2.1089761144150042E-7, 2.2110444751291776E-7, 2.327945619868283E-7,
                     2.4133042526817403E-7, 2.5079609750076813E-7, 2.606298840087027E-7, 2.6837634878705996E-7, 
                     2.748566427180845E-7, 2.827357443443751E-7, 2.8941995189186364E-7, 2.9448045086319335E-7, 
                     3.0042919445043474E-7, 3.0513243974666165E-7, 3.091559743893151E-7, 3.125491970932999E-7, 
                     3.151066872077333E-7, 3.1766271203670685E-7, 3.1952789059097915E-7, 3.208157319319378E-7, 
                     3.2073738058588197E-7, 3.213912694816712E-7, 3.2024960363440477E-7, 3.189288192652561E-7, 
                     3.178555731915086E-7, 3.145714946723404E-7, 3.1090668692483294E-7, 3.0702295241546354E-7, 
                     3.0280912326346043E-7, 2.967320418029814E-7, 2.9112551003702895E-7, 2.8421398692133847E-7, 
                     2.7803218566873933E-7, 2.7143497724611087E-7, 2.6187540609427093E-7, 2.532234947833085E-7, 
                     2.4384453154478683E-7, 2.3285028997588115E-7, 2.2147169025012526E-7, 2.101232060469469E-7, 
                     1.9750667792181904E-7, 1.8488574311991692E-7], 10**6)
#w=np.max(ydata)
#ydata = [-w+y for y in ydata]
#data in um

# %%
guess_r = -xdata[-1] / np.tan(2*np.arctan(xdata[-1]/ydata[-1]))
guess = [guess_r, -guess_r+ydata[0]]
popt, pcov = curve_fit(circle, xdata, ydata, p0=guess)
print(guess)
# Out:
# [342272199.6568475, -342272199.507253]

# %%
x_fit = np.arange(-11.5*10**3, 11.5*10**3, 100)
y_fit = circle(x_fit, popt[0], popt[1])
#u = np.max(y_fit)
#y_fit = [-u+y for y in y_fit]

plt.figure()
plt.plot(xdata*10**(-3), ydata, 'k.')
plt.plot(x_fit*10**(-3), y_fit, 'r-')
plt.xlabel('pos from center of the window (mm)')
plt.ylabel('deformation (um)')
plt.title('diameter of the window: 45 mm')

plt.show()

print('radius of curvature:', popt[0]*10**(-6), 'm')
# Out:
# radius of curvature: 342.57131536152224 m

# %%
#55 mm window

# %%
#xdir

# %%
xdata = np.multiply(np.arange(-11.25, 11.75, 0.5), 10**3)
ydata = np.multiply([1.793717628525659E-7, 1.899929467069049E-7, 2.032353610427067E-7, 2.141710095817382E-7, 
                     2.2464453775786491E-7, 2.350292298994125E-7, 2.4363154018329835E-7, 2.5427396949903217E-7, 
                     2.611472803976191E-7, 2.6927557216063246E-7, 2.7774168927310707E-7, 2.8391377499426097E-7, 
                     2.886885651198405E-7, 2.9522790862725396E-7, 3.005372809314887E-7, 3.0402671203234796E-7, 
                     3.0862843732152336E-7, 3.1192466368558257E-7, 3.14603676845565E-7, 3.1668216838645516E-7, 
                     3.1799541709450597E-7, 3.1934559446195294E-7, 3.2006979842347845E-7, 3.2028998877604515E-7, 
                     3.1921570860081547E-7, 3.1894023790281873E-7, 3.169575301800626E-7, 3.148738793677624E-7, 
                     3.1306252087201524E-7, 3.091955013269756E-7, 3.0498699089396595E-7, 3.007385816782849E-7, 
                     2.9609935070738637E-7, 2.897842638829029E-7, 2.8398783020732143E-7, 2.770952584368937E-7, 
                     2.7065327901140153E-7, 2.6397770050969745E-7, 2.5462936918177924E-7, 2.4608046817583117E-7, 
                     2.3690447476628041E-7, 2.264476393969468E-7, 2.1555494849338168E-7, 2.045459001120219E-7, 
                     1.9259038451647863E-7, 1.8045972455971254E-7], 10**6)
#w=np.max(ydata)
#ydata = [-w+y for y in ydata]
#data in um

# %%
guess_r = -xdata[-1] / np.tan(2*np.arctan(xdata[-1]/ydata[-1]))
guess = [guess_r, -guess_r+ydata[0]]
popt, pcov = curve_fit(circle, xdata, ydata, p0=guess)
print(guess)
# Out:
# [350666887.7949781, -350666887.6156063]

# %%
x_fit = np.arange(-11.5*10**3, 11.5*10**3, 100)
y_fit = circle(x_fit, popt[0], popt[1])
#u = np.max(y_fit)
#y_fit = [-u+y for y in y_fit]

plt.figure()
plt.plot(xdata*10**(-3), ydata, 'k.')
plt.plot(x_fit*10**(-3), y_fit, 'r-')
plt.xlabel('pos from center of the window (mm)')
plt.ylabel('deformation (um)')
plt.title('diameter of the window: 55 mm')

plt.show()

print('radius of curvature:', popt[0]*10**(-6), 'm')
# Out:
# radius of curvature: 352.46685684918975 m

# %%
#ydir

# %%
xdata = np.multiply(np.arange(-11.25, 11.75, 0.5), 10**3)
ydata = np.multiply([1.4959448130650004E-7, 1.6177021746910015E-7, 1.757188664805475E-7, 1.8758541517958419E-7, 
                     1.994052227894942E-7, 2.1089761144150042E-7, 2.2110444751291776E-7, 2.327945619868283E-7, 
                     2.4133042526817403E-7, 2.5079609750076813E-7, 2.606298840087027E-7, 2.6837634878705996E-7, 
                     2.748566427180845E-7, 2.827357443443751E-7, 2.8941995189186364E-7, 2.9448045086319335E-7, 
                     3.0042919445043474E-7, 3.0513243974666165E-7, 3.091559743893151E-7, 3.125491970932999E-7, 
                     3.151066872077333E-7, 3.1766271203670685E-7, 3.1952789059097915E-7, 3.208157319319378E-7, 
                     3.2073738058588197E-7, 3.213912694816712E-7, 3.2024960363440477E-7, 3.189288192652561E-7, 
                     3.178555731915086E-7, 3.145714946723404E-7, 3.1090668692483294E-7, 3.0702295241546354E-7, 
                     3.0280912326346043E-7, 2.967320418029814E-7, 2.9112551003702895E-7, 2.8421398692133847E-7, 
                     2.7803218566873933E-7, 2.7143497724611087E-7, 2.6187540609427093E-7, 2.532234947833085E-7, 
                     2.4384453154478683E-7, 2.3285028997588115E-7, 2.2147169025012526E-7, 2.101232060469469E-7, 
                     1.9750667792181904E-7, 1.8488574311991692E-7], 10**6)
#w=np.max(ydata)
#ydata = [-w+y for y in ydata]
#data in um

# %%
guess_r = -xdata[-1] / np.tan(2*np.arctan(xdata[-1]/ydata[-1]))
guess = [guess_r, -guess_r+ydata[0]]
popt, pcov = curve_fit(circle, xdata, ydata, p0=guess)
print(guess)
# Out:
# [342272199.6568475, -342272199.507253]

# %%
x_fit = np.arange(-11.5*10**3, 11.5*10**3, 100)
y_fit = circle(x_fit, popt[0], popt[1])
#u = np.max(y_fit)
#y_fit = [-u+y for y in y_fit]

plt.figure()
plt.plot(xdata*10**(-3), ydata, 'k.')
plt.plot(x_fit*10**(-3), y_fit, 'r-')
plt.xlabel('pos from center of the window (mm)')
plt.ylabel('deformation (um)')
plt.title('diameter of the window: 55 mm')

plt.show()

print('radius of curvature:', popt[0]*10**(-6), 'm')
# Out:
# radius of curvature: 342.57131536152224 m

# %%
#65 mm window

# %%
#xdir

# %%
xdata = np.multiply(np.arange(-11.25, 11.75, 0.5), 10**3)
ydata = np.multiply([2.800726137933411E-7, 2.863781267868384E-7, 2.940553276472773E-7, 2.994910683085896E-7, 
                     3.0554343885764304E-7, 3.118648128457185E-7, 3.164224291558674E-7, 3.2287049709786093E-7, 
                     3.2571072843994056E-7, 3.315922722716198E-7, 3.350570132720627E-7, 3.3853775943722627E-7, 
                     3.4323396331549215E-7, 3.4686084131952577E-7, 3.476077884627208E-7, 3.518327903171332E-7, 
                     3.548799932419283E-7, 3.55730685439165E-7, 3.577029251110233E-7, 3.579154135852366E-7, 
                     3.591016996684291E-7, 3.601412958250616E-7, 3.6039277041616227E-7, 3.604883939900588E-7, 
                     3.5967612257959777E-7, 3.6111991451038E-7, 3.5782929641695346E-7, 3.5642074331456814E-7, 
                     3.553297002631863E-7, 3.5346985286399594E-7, 3.5123483094402727E-7, 3.4826266228302096E-7, 
                     3.4556345407461557E-7, 3.4350813862843964E-7, 3.405483616473919E-7, 3.3635874375194293E-7, 
                     3.317644540906949E-7, 3.2615833567798005E-7, 3.2238222634408647E-7, 3.173440385210314E-7, 
                     3.116348669136696E-7, 3.06554988570405E-7, 3.004950288044325E-7, 2.9395494999983416E-7, 
                     2.879783486387529E-7, 2.808477958510299E-7], 10**6)
#w=np.max(ydata)
#ydata = [-w+y for y in ydata]
#data in um

# %%
###### guess_r = -xdata[-1] / np.tan(2*np.arctan(xdata[-1]/ydata[-1]))
guess_r = 100E6
guess = [guess_r, -guess_r+ydata[24]]
popt, pcov = curve_fit(circle, xdata, ydata, p0=guess)
print(guess)
# Out:
# [100000000.0, -99999999.64032388]

# %%
x_fit = np.arange(-11.5*10**3, 11.5*10**3, 100)
#y_fit = circle(x_fit, popt[0], popt[1])
y_fit = circle(x_fit, popt[0], popt[1])
#u = np.max(y_fit)
#y_fit = [-u+y for y in y_fit]

plt.figure()
plt.plot(xdata*10**(-3), ydata, 'k.')
plt.plot(x_fit*10**(-3), y_fit, 'r-')
plt.xlabel('pos from center of the window (mm)')
plt.ylabel('deformation (um)')
plt.title('diameter of the window: 65 mm')

plt.show()

print('radius of curvature:', popt[0]*10**(-6), 'm')
# Out:
# radius of curvature: 195.65413535361094 m

# %%
#ydir

# %%
xdata = np.multiply(np.arange(-11.25, 11.75, 0.5), 10**3)
ydata = np.multiply([2.6636557080353187E-7, 2.738357497329306E-7, 2.8233219071901087E-7, 2.8864218897116136E-7, 
                     2.95438728007202E-7, 3.02776814562444E-7, 3.079386172479529E-7, 3.1540252146956306E-7, 
                     3.1897752446441465E-7, 3.256699946671892E-7, 3.295206882363588E-7, 3.337476288295787E-7, 
                     3.3913697107430716E-7, 3.4338636814180397E-7, 3.4467370845710946E-7, 3.4928389354093065E-7, 
                     3.5284659220248414E-7, 3.5410292258273695E-7, 3.5645109235145513E-7, 3.569827789010982E-7, 
                     3.585112341197259E-7, 3.59811396076543E-7, 3.6028642395799935E-7, 3.6058291501495283E-7, 
                     3.5994192188319587E-7, 3.6147634757353275E-7, 3.583013603345652E-7, 3.570147970692783E-7, 
                     3.5594242043379404E-7, 3.541373421557176E-7, 3.5176088509256726E-7, 3.487660236045975E-7, 
                     3.460143727468851E-7, 3.4371943920319896E-7, 3.405703264758712E-7, 3.3630568032927593E-7, 
                     3.315694812732588E-7, 3.258677703004201E-7, 3.218085429310692E-7, 3.166684580990492E-7, 
                     3.1073534080176335E-7, 3.0535683576246527E-7, 2.989508286449077E-7, 2.9207695430105284E-7, 
                     2.8584187656925574E-7, 2.786481612255329E-7], 10**6)
#w=np.max(ydata)
#ydata = [-w+y for y in ydata]
#data in um

# %%
guess_r = -xdata[-1] / np.tan(2*np.arctan(xdata[-1]/ydata[-1]))
guess = [guess_r, -guess_r+ydata[24]]
popt, pcov = curve_fit(circle, xdata, ydata, p0=guess)
print(guess)
# Out:
# [227100906.3291463, -227100905.96920437]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in sqrt

# %%
x_fit = np.arange(-11.5*10**3, 11.5*10**3, 100)
y_fit = circle(x_fit, popt[0], popt[1])
#u = np.max(y_fit)
#y_fit = [-u+y for y in y_fit]

plt.figure()
plt.plot(xdata*10**(-3), ydata, 'k.')
plt.plot(x_fit*10**(-3), y_fit, 'r-')
plt.xlabel('pos from center of the window (mm)')
plt.ylabel('deformation (um)')
plt.title('diameter of the window: 65 mm')

plt.show()

print('radius of curvature:', popt[0]*10**(-6), 'm')
# Out:
# radius of curvature: 224.2996258494397 m
